# %% [markdown]
# <a href="https://colab.research.google.com/github/ranawat-manvendra1011/learning-CPP/blob/main/exp_2_1(practice_bike_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.5'

# %%
from pycaret.datasets import get_data

# %%
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# ...

# %%
bikeDataSet = get_data("bike")
# Out:
#    instant    dteday  season  yr  mnth  ...  temp   atemp   hum  windspeed  cnt
# 0        1  1/1/2011       1   0     1  ...  0.24  0.2879  0.81        0.0   16
# 1        2  1/1/2011       1   0     1  ...  0.22  0.2727  0.80        0.0   40
# 2        3  1/1/2011       1   0     1  ...  0.22  0.2727  0.80        0.0   32
# 3        4  1/1/2011       1   0     1  ...  0.24  0.2879  0.75        0.0   13
# 4        5  1/1/2011       1   0     1  ...  0.24  0.2879  0.75        0.0    1
#
# [5 rows x 15 columns]

# %%
bikeDataSet.head(17379)
# Out:
#        instant      dteday  season  yr  ...   atemp   hum  windspeed  cnt
# 0            1    1/1/2011       1   0  ...  0.2879  0.81     0.0000   16
# 1            2    1/1/2011       1   0  ...  0.2727  0.80     0.0000   40
# 2            3    1/1/2011       1   0  ...  0.2727  0.80     0.0000   32
# 3            4    1/1/2011       1   0  ...  0.2879  0.75     0.0000   13
# 4            5    1/1/2011       1   0  ...  0.2879  0.75     0.0000    1
# ...        ...         ...     ...  ..  ...     ...   ...        ...  ...
# 17374    17375  12/31/2012       1   1  ...  0.2576  0.60     0.1642  119
# 17375    17376  12/31/2012       1   1  ...  0.2576  0.60     0.1642   89
# 17376    17377  12/31/2012       1   1  ...  0.2576  0.60     0.1642   90
# 17377    17378  12/31/2012       1   1  ...  0.2727  0.56     0.1343   61
# 17378    17379  12/31/2012       1   1  ...  0.2727  0.65     0.1343   49
#
# [17379 rows x 15 columns]

# %%
bikeDataSet.shape
# Out:
# (17379, 15)

# %%
from pycaret.regression import *

# %%
exp_reg = setup(bikeDataSet , target = 'cnt')

#Press Shift + Tab to navigate to chat history
# Out:
#                                Description             Value
# 0                               session_id              1060
# 1                                   Target               cnt
# 2                            Original Data       (17379, 15)
# 3                           Missing Values             False
# 4                         Numeric Features                 6
# 5                     Categorical Features                 7
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (12165, 37)
# 10                    Transformed Test Set        (5214, 37)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
rfmodel = create_model('rf')
# Out:
#           MAE        MSE     RMSE      R2   RMSLE    MAPE
# 0     25.1203  1674.9568  40.9262  0.9492  0.3382  0.3082
# 1     24.4772  1391.5893  37.3040  0.9570  0.3307  0.3020
# 2     26.6552  2053.1957  45.3122  0.9375  0.3466  0.3187
# 3     25.6621  1683.8271  41.0345  0.9476  0.3614  0.3491
# 4     27.9508  2329.6057  48.2660  0.9267  0.3627  0.3350
# 5     26.4330  1888.9851  43.4625  0.9380  0.3506  0.3283
# 6     26.0327  1768.8830  42.0581  0.9458  0.3304  0.3120
# 7     26.9537  2093.0045  45.7494  0.9393  0.3563  0.3287
# 8     25.6199  1866.0785  43.1981  0.9442  0.3258  0.2955
# 9     25.8416  1789.4993  42.3025  0.9465  0.3298  0.2934
# Mean  26.0746  1853.9625  42.9613  0.9432  0.3432  0.3171
# SD     0.9303   247.1066   2.8785  0.0078  0.0133  0.0172

# %%
cm= compare_models()
#cmd to compare bike datasets with otheres
# Out:
#                                     Model          MAE           MSE  \
# et                  Extra Trees Regressor      24.9612  1.661832e+03
# lightgbm  Light Gradient Boosting Machine      26.4252  1.742727e+03
# rf                Random Forest Regressor      26.0746  1.853963e+03
# dt                Decision Tree Regressor      35.3381  3.621819e+03
# knn                 K Neighbors Regressor      42.1826  4.349415e+03
# gbr           Gradient Boosting Regressor      48.3364  5.086118e+03
# ada                    AdaBoost Regressor      88.9979  1.172891e+04
# ridge                    Ridge Regression     104.4353  1.949616e+04
# br                         Bayesian Ridge     104.4296  1.949605e+04
# lr                      Linear Regression     104.4364  1.949752e+04
# lasso                    Lasso Regression     104.3801  1.974980e+04
# huber                     Huber Regressor      99.3934  2.061487e+04
# omp           Orthogonal Matching Pursuit     109.9798  2.172521e+04
# ...

# %%
sm=save_model(rfmodel, 'rfmodelfile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
rfmodel=load_model('rfmodelfile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
newdataset=get_data("bike").iloc[:5]
#cnt is dependent\targert variable
#upto windspeed  all are independent variable
# Out:
#    instant    dteday  season  yr  mnth  ...  temp   atemp   hum  windspeed  cnt
# 0        1  1/1/2011       1   0     1  ...  0.24  0.2879  0.81        0.0   16
# 1        2  1/1/2011       1   0     1  ...  0.22  0.2727  0.80        0.0   40
# 2        3  1/1/2011       1   0     1  ...  0.22  0.2727  0.80        0.0   32
# 3        4  1/1/2011       1   0     1  ...  0.24  0.2879  0.75        0.0   13
# 4        5  1/1/2011       1   0     1  ...  0.24  0.2879  0.75        0.0    1
#
# [5 rows x 15 columns]

# %%
newpredictions=predict_model(rfmodel, data=newdataset)

newpredictions
# Out:
#    instant    dteday  season  yr  mnth  ...   atemp   hum  windspeed  cnt  Label
# 0        1  1/1/2011       1   0     1  ...  0.2879  0.81        0.0   16  36.85
# 1        2  1/1/2011       1   0     1  ...  0.2727  0.80        0.0   40  35.49
# 2        3  1/1/2011       1   0     1  ...  0.2727  0.80        0.0   32  18.62
# 3        4  1/1/2011       1   0     1  ...  0.2879  0.75        0.0   13  12.79
# 4        5  1/1/2011       1   0     1  ...  0.2879  0.75        0.0    1   5.01
#
# [5 rows x 16 columns]

# %%
import matplotlib.pyplot as plt

# %%
predicted = newpredictions.iloc[:,-1]     # Last column
actual = newpredictions.iloc[:,-2]        # 2nd last column

plt.scatter(actual, predicted)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Actul Vs Predicted')
plt.savefig("result-scatter-plot.jpg", dpi=300)
plt.show()
